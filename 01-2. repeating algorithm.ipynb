# %% [markdown]
# # 1부터 n까지 정수의 합 구하기 (while 문)

# %%
print("지금부터 1부터 n까지의 합을 구하겠습니다.")
n=int(input('n값을 입력하시오: '))

sum=0
i=1

while i <= n:   #i가 n보다 작거나 같을 때까지 반복
    sum += i
    i += 1

print(f"1부터 {n}까지의 합은 {sum}입니다.")
print(f"i값은 {i}입니다.")
# Out:
# 지금부터 1부터 n까지의 합을 구하겠습니다.
# 1부터 6까지의 합은 21입니다.
# i값은 7입니다.

# %% [markdown]
# # 1부터 n까지 정수의 합 구하기 (for 문)

# %% [markdown]
# 변수가 하나만 있을 때는 while문보다 for문 사용하는 것이 더 좋다

# %%
print("1부터 n까지의 합을 구하자.")
n = int(input("n의 값을 입력하시오.: "))

sum = 0 
for i in range(1,n+1):
    sum += i 

print(f"1부터 {n}까지의 합은 {sum}이다.")
print(f"i={i}")

# iterable: 반복할 수 있는 개체 i를 말함 , range()함수가 iterable object를 생성하는 것
# range(n): 0이상 n미만인 수를 차례로 나열하는 수열
# range(a,b): a이상 b미만인 수를 차례로 나열하는 수열
# range(a,b,n): a이상 b 미만인 수를 n간격으로 나열하는 수열

# PYTHON iterable object: list, str, tuple
# Out:
# 1부터 n까지의 합을 구하자.
# 1부터 5까지의 합은 15이다.
# i=5

# %% [markdown]
# # a부터 b까지 정수의 합 구하기 (for문)

# %%
print("a부터 b까지의 합을 구하자.")
a = int(input("a=?: "))
b = int(input("b=?: "))

if a > b:
    a,b = b,a       # a와 b의 값을 교환(단일 대입문 사용)

sum=0
for i in range(a,b+1):
    sum += i
print(f"{a}부터 {b}까지의 합은 {sum}이다.")
# Out:
# a부터 b까지의 합을 구하자.
# 3부터 8까지의 합은 33이다.

# %% [markdown]
# # 반복 과정에서 조건 판단하기 1

# %%
#a부터 b까지 정수의 합을 구하는 과정과 최종값을 구하는 프로그램
print("a부터 b까지의 합을 구하자.")
a = int(input("a=?: "))
b = int(input("b=?: "))

if a > b:
    a,b = b,a       

sum=0
for i in range(a,b+1):
    if i<b: print(f"{i}+",end='')       #print('~~', end=''): ~~출력하고 그 아래 출력물을 바로 옆에 이어서 출력하기 
    else: print(f"{i}=", end='')
    sum += i

print(sum)
# Out:
# a부터 b까지의 합을 구하자.
# 3+4+5+6=18

# %%
print("a부터 b까지의 합을 구하자.")
a = int(input("a=?: "))
b = int(input("b=?: "))

if a > b:
    a,b = b,a 

sum=0

for i in range(a,b):
    print(f"{i}+", end='')
    sum += i
sum += b

print(f"{b}={sum}")
# Out:
# a부터 b까지의 합을 구하자.
# 3+4+5+6=18

# %% [markdown]
# # 반복 과정에서 조건 판단하기 2

# %%
# +와 -를 번갈아 출력하기 1 _ 나눗셈 n번 시행

print("+와 -를 번갈아 출력합니다.")
n = int(input("몇 개를 출력할까요?: "))
for i in range(n):
    if i%2==0:
        print('+',end='')
    else:
        print('-',end='')
# Out:
# +와 -를 번갈아 출력합니다.
# +-+-+-+-+-+-

# %%
# +와 -를 번갈아 출력하기 2 _ 나눗셈 2번 시행

print("+와 -를 번갈아 출력합니다.")
n = int(input("몇 개를 출력할까요?: "))
for _ in range(n//2):
    print('+-',end='')
if n%2==1:
    print('+',end='')
# Out:
# +와 -를 번갈아 출력합니다.
# +-+-+-+-+-+-+

# %%
if 14%2:
    print('a')
else:
    print('b')  # if 14%2: 라는 것은 14를 2로 나눈 나머지가 1이냐는 뜻

print(23%4)     # 나머지
print(23//4)    # 몫
# Out:
# b
# 3
# 5

# %% [markdown]
# # 반복 과정에서 조건 판단하기 3

# %%
# *를 n개 출력하되 w개마다 줄바꿈하기 1

print("*를 출력합니다.")
n = int(input('몇 개를 출력할까요?: '))
w = int(input("몇 개마다 줄바꿈할까요?:"))

for i in range(n):
    print('*',end='')
    if i%w==w-1:
        print()
# Out:
# *를 출력합니다.
# ***
# ***
# ***
# *

# %%
# *를 n개 출력하되 w개마다 줄바꿈하기 2

print("*를 출력합니다.")
n = int(input('몇 개를 출력할까요?: '))
w = int(input("몇 개마다 줄바꿈할까요?:"))

for i in range(n//w):
    print('*'*w,end='')
    print()
a = n%w
if a:
    print('*'* a)    
print()
# Out:
# *를 출력합니다.
# ***
# ***
# ***
# *

# %% [markdown]
# 양수만 입력받기
